# %%
# !pip install pulp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pulp in /home/veleref/.local/lib/python3.10/site-packages (2.8.0)

# %%
import random
from itertools import permutations
from pulp import LpProblem, LpVariable, LpStatus, LpMinimize, lpSum
from typing import Dict, List, Tuple
from pulp import GLPK_CMD

def generate_dummy_data(n_pois: int, n_days: int) -> tuple:
    """
    Generate dummy data for the itinerary optimization problem.

    Parameters:
    - n_pois: The number of points of interest (POIs).
    - n_days: The number of days.

    Returns:
    - pois: A list of POI names.
    - days: A list of day identifiers.
    - travel_time: A dictionary with travel times between each pair of POIs.
    """
    pois = [f'poi_{i}' for i in range(n_pois)]
    days = [f'D{day}' for day in range(1, n_days + 1)]
    travel_time = {(poi1, poi2): random.randint(10, 60) for poi1, poi2 in permutations(pois, 2)}
    return pois, days, travel_time



def extract_itinerary(nodes):
    # Step 1: Group nodes by day
    day_edges = {}
    for node in nodes:
        poi1, poi2, day = node
        if day not in day_edges:
            day_edges[day] = []
        day_edges[day].append((poi1, poi2))
    
    itineraries = {}
    # Step 2: Construct the graph for each day and find the path
    for day, edges in day_edges.items():
        graph = {}
        in_degree = {}  # Track incoming edges
        for poi1, poi2 in edges:
            graph[poi1] = poi2
            # Update in_degree counts
            in_degree[poi2] = in_degree.get(poi2, 0) + 1
            if poi1 not in in_degree:
                in_degree[poi1] = 0
        
        # Step 3: Find the starting POI (no incoming edges) and construct the itinerary
        start_poi = None
        for poi, in_deg in in_degree.items():
            if in_deg == 0:
                start_poi = poi
                break
        
        itinerary = [start_poi]
        while start_poi in graph:
            next_poi = graph[start_poi]
            itinerary.append(next_poi)
            start_poi = next_poi
        
        itineraries[day] = itinerary
    
    return itineraries

# %%
# Initialize data
n_pois = 100  # Number of POIs
n_days = 20  # Number of days
pois, days, travel_time = generate_dummy_data(n_pois, n_days)

# Initialize the problem
problem = LpProblem("Itinerary_Optimization", LpMinimize)

# Variables
order_vars = {
    (poi1, poi2, day): LpVariable(f"order_{poi1}_{poi2}_{day}", cat="Binary")
    for poi1 in pois + ['nonce_node'] for poi2 in pois + ['nonce_node'] 
    for day in days if poi1 != poi2
}
# Objective function: Minimize the total travel time
problem += lpSum(
    travel_time[(poi_from, poi_to)] * order_vars[(poi_from, poi_to, day)]
    for poi_from, poi_to in permutations(pois, 2) for day in days
)

# Constraints

# Each POI visited exactly once across all days
for poi in pois:
    problem += lpSum(
        order_vars[(poi, other_poi, day)] + order_vars[(other_poi, poi, day)]
        for day in days for other_poi in pois + ['nonce_node'] if poi != other_poi
    ) == 2, f"enter_and_exit_{poi}"

# Ensure that starting nonce_nodes are visited n_days times
problem += lpSum(order_vars[('nonce_node', poi, day)] 
                 for poi in pois for day in days) == n_days, "start_nonce"

# Ensure that ending nonce_nodes are visited n_days times
problem += lpSum(order_vars[(poi, 'nonce_node', day)] 
                 for poi in pois for day in days) == n_days, "end_nonce"

for day in days:
    problem += lpSum(
        order_vars[('nonce_node', poi, day)] 
        for poi in pois) == 1, f"start_nonce_{day}"
    problem += lpSum(
        order_vars[(poi, 'nonce_node', day)] 
        for poi in pois) == 1, f"end_nonce_{day}"


# Ensure entering and exiting each POI occurs within the same day
for day in days:
    for poi in pois:
        problem += lpSum(
            order_vars[(poi, other_poi, day)]
            for other_poi in pois + ['nonce_node'] if poi != other_poi
        ) == lpSum(
            order_vars[(other_poi, poi, day)]
            for other_poi in pois + ['nonce_node'] if poi != other_poi
        ), f"same_day_visit_{poi}_{day}"


# problem
# Solve the problem
status = problem.solve(GLPK_CMD(msg=0))

# Check the status and print the results
if LpStatus[status] == 'Optimal':
    print("Solution Found:\n")
    results = []
    for var in order_vars:
        if order_vars[var].varValue == 1:
            results.append(var)
            print(f"{var} = {order_vars[var].varValue}")
else:
    print("No optimal solution found.")
# Out:
# Solution Found:
#
# ('poi_0', 'nonce_node', 'D15') = 1
# ('poi_1', 'nonce_node', 'D13') = 1
# ('poi_2', 'poi_55', 'D20') = 1
# ('poi_3', 'poi_30', 'D15') = 1
# ('poi_4', 'poi_91', 'D4') = 1
# ('poi_5', 'poi_53', 'D18') = 1
# ('poi_6', 'poi_57', 'D10') = 1
# ('poi_7', 'poi_62', 'D9') = 1
# ('poi_8', 'poi_41', 'D5') = 1
# ('poi_9', 'poi_61', 'D5') = 1
# ('poi_10', 'poi_7', 'D9') = 1
# ('poi_11', 'poi_16', 'D4') = 1
# ('poi_12', 'poi_0', 'D15') = 1
# ('poi_13', 'poi_76', 'D15') = 1
# ('poi_14', 'poi_90', 'D19') = 1
# ('poi_15', 'nonce_node', 'D18') = 1
# ('poi_16', 'poi_4', 'D4') = 1
# ('poi_17', 'nonce_node', 'D2') = 1
# ('poi_18', 'poi_94', 'D11') = 1
# ('poi_19', 'poi_6', 'D10') = 1
# ('poi_20', 'poi_26', 'D5') = 1
# ('poi_21', 'poi_65', 'D6') = 1
# ('poi_22', 'poi_31', 'D20') = 1
# ('poi_23', 'poi_13', 'D15') = 1
# ('poi_24', 'poi_42', 'D9') = 1
# ('poi_25', 'poi_27', 'D15') = 1
# ('poi_26', 'nonce_node', 'D5') = 1
# ('poi_27', 'poi_50', 'D15') = 1
# ('poi_28', 'poi_92', 'D15') = 1
# ('poi_29', 'nonce_node', 'D16') = 1
# ('poi_30', 'poi_25', 'D15') = 1
# ('poi_31', 'poi_2', 'D20') = 1
# ('poi_32', 'nonce_node', 'D9') = 1
# ('poi_33', 'poi_95', 'D13') = 1
# ('poi_34', 'poi_48', 'D9') = 1
# ('poi_35', 'poi_20', 'D5') = 1
# ('poi_36', 'poi_15', 'D18') = 1
# ('poi_37', 'poi_59', 'D1') = 1
# ('poi_38', 'poi_51', 'D15') = 1
# ('poi_39', 'poi_69', 'D15') = 1
# ('poi_40', 'poi_72', 'D15') = 1
# ('poi_41', 'poi_46', 'D5') = 1
# ('poi_42', 'poi_87', 'D9') = 1
# ('poi_43', 'poi_73', 'D9') = 1
# ('poi_44', 'poi_29', 'D16') = 1
# ('poi_45', 'poi_70', 'D3') = 1
# ('poi_46', 'poi_9', 'D5') = 1
# ('poi_47', 'poi_84', 'D17') = 1
# ('poi_48', 'poi_68', 'D9') = 1
# ('poi_49', 'nonce_node', 'D1') = 1
# ('poi_50', 'poi_12', 'D15') = 1
# ('poi_51', 'poi_28', 'D15') = 1
# ('poi_52', 'poi_71', 'D9') = 1
# ('poi_53', 'poi_36', 'D18') = 1
# ('poi_54', 'poi_44', 'D16') = 1
# ('poi_55', 'nonce_node', 'D20') = 1
# ('poi_56', 'poi_54', 'D16') = 1
# ('poi_57', 'nonce_node', 'D10') = 1
# ('poi_58', 'nonce_node', 'D8') = 1
# ('poi_59', 'poi_49', 'D1') = 1
# ('poi_60', 'poi_82', 'D11') = 1
# ('poi_61', 'poi_35', 'D5') = 1
# ('poi_62', 'poi_97', 'D9') = 1
# ('poi_63', 'nonce_node', 'D11') = 1
# ('poi_64', 'poi_88', 'D9') = 1
# ('poi_65', 'nonce_node', 'D6') = 1
# ('poi_66', 'poi_79', 'D7') = 1
# ('poi_67', 'poi_19', 'D10') = 1
# ('poi_68', 'poi_52', 'D9') = 1
# ('poi_69', 'poi_23', 'D15') = 1
# ('poi_70', 'nonce_node', 'D3') = 1
# ('poi_71', 'poi_43', 'D9') = 1
# ('poi_72', 'poi_3', 'D15') = 1
# ('poi_73', 'poi_93', 'D9') = 1
# ('poi_74', 'poi_21', 'D6') = 1
# ('poi_75', 'poi_11', 'D4') = 1
# ('poi_76', 'poi_38', 'D15') = 1
# ('poi_77', 'poi_78', 'D12') = 1
# ('poi_78', 'nonce_node', 'D12') = 1
# ('poi_79', 'nonce_node', 'D7') = 1
# ('poi_80', 'nonce_node', 'D19') = 1
# ('poi_81', 'poi_64', 'D9') = 1
# ('poi_82', 'poi_63', 'D11') = 1
# ('poi_83', 'poi_40', 'D15') = 1
# ('poi_84', 'nonce_node', 'D17') = 1
# ('poi_85', 'poi_8', 'D5') = 1
# ('poi_86', 'nonce_node', 'D14') = 1
# ('poi_87', 'poi_10', 'D9') = 1
# ('poi_88', 'poi_34', 'D9') = 1
# ('poi_89', 'poi_83', 'D15') = 1
# ('poi_90', 'poi_80', 'D19') = 1
# ('poi_91', 'nonce_node', 'D4') = 1
# ('poi_92', 'poi_39', 'D15') = 1
# ('poi_93', 'poi_81', 'D9') = 1
# ('poi_94', 'poi_60', 'D11') = 1
# ('poi_95', 'poi_1', 'D13') = 1
# ('poi_96', 'poi_5', 'D18') = 1
# ('poi_97', 'poi_32', 'D9') = 1
# ('poi_98', 'poi_66', 'D7') = 1
# ('poi_99', 'poi_77', 'D12') = 1
# ('nonce_node', 'poi_14', 'D19') = 1
# ('nonce_node', 'poi_17', 'D2') = 1
# ('nonce_node', 'poi_18', 'D11') = 1
# ('nonce_node', 'poi_22', 'D20') = 1
# ('nonce_node', 'poi_24', 'D9') = 1
# ('nonce_node', 'poi_33', 'D13') = 1
# ('nonce_node', 'poi_37', 'D1') = 1
# ('nonce_node', 'poi_45', 'D3') = 1
# ('nonce_node', 'poi_47', 'D17') = 1
# ('nonce_node', 'poi_56', 'D16') = 1
# ('nonce_node', 'poi_58', 'D8') = 1
# ('nonce_node', 'poi_67', 'D10') = 1
# ('nonce_node', 'poi_74', 'D6') = 1
# ('nonce_node', 'poi_75', 'D4') = 1
# ('nonce_node', 'poi_85', 'D5') = 1
# ('nonce_node', 'poi_86', 'D14') = 1
# ('nonce_node', 'poi_89', 'D15') = 1
# ('nonce_node', 'poi_96', 'D18') = 1
# ('nonce_node', 'poi_98', 'D7') = 1
# ('nonce_node', 'poi_99', 'D12') = 1
